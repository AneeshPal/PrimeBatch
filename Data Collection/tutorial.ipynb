# %%
# Data Colection ways:-
# 1.Kaggle
# 2.DB SQL
# 3.Devices

# Sources:-
# 1. Primary
# 2. Secondary

# Garbage In Garbage Out

# SQL database data collection benefits:
# 1. reliable
# 2. relevant
# 3. cost effective
